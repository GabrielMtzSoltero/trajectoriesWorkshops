# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielMtzSoltero/trajectoriesWorkshops/blob/main/Trajectories_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
import cv2
from google.colab.patches import cv2_imshow

#Creamos una imagen negra
cuadro = np.zeros((100, 100, 3), dtype=np.uint8)

#accedemos a una parte de la imagen anterior para ponerle negro
cuadro[20:80, 20:80] = [255, 255, 255]

#modificamos un canal
#cuadro[:, :, 1] = 0 # Eliminamos el rojo del canal 2 (BGR)

print("Imagen generada puramente con NumPy:")
cv2_imshow(cuadro)
# Out:
# Imagen generada puramente con NumPy:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
# Leemos la imagen
# cv2.imread devuelve None si el archivo no se encuentra o no se puede leer
img_elmo = cv2.imread('elmoCookie.jpg')
cv2_imshow(img_elmo)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
img_liz1 = cv2.imread('liz.jpg')
cv2_imshow(img_liz1)
# Out:
# <PIL.Image.Image image mode=RGB size=750x755>

# %%
img_liz2 = cv2.imread('liz2.jpg',cv2.IMREAD_GRAYSCALE)
cv2_imshow(img_liz2)
# Out:
# <PIL.Image.Image image mode=L size=750x755>

# %%
img_liz3 = cv2.imread('liz3.jpg',cv2.IMREAD_UNCHANGED)
cv2_imshow(img_liz3)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
